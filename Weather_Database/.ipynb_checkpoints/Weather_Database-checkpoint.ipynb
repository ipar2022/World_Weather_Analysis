# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
#lat_lngs = # YOUR CODE HERE
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
#from datetime import datetime

# Import the OpenWeatherMap's API key
from config import api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#                          "Country": city_country,
#                          "Date": city_date,

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto narino
# Processing Record 2 of Set 1 | inhambane
# Processing Record 3 of Set 1 | tura
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | menongue
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | pangnirtung
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | dicabisagan
# Processing Record 15 of Set 1 | bitung
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | sorland
# Processing Record 18 of Set 1 | tual
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | monteagudo
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | yulara
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | dingli
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | luba
# Processing Record 27 of Set 1 | dafeng
# Processing Record 28 of Set 1 | namwala
# Processing Record 29 of Set 1 | salinopolis
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | camabatela
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | helong
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | pangody
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | jaisinghnagar
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | villa guerrero
# Processing Record 41 of Set 1 | alyangula
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | pringsewu
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | hay river
# Processing Record 47 of Set 1 | leningradskiy
# Processing Record 48 of Set 1 | tornio
# Processing Record 49 of Set 1 | te anau
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | tucuma
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | alice springs
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | ankazoabo
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | monrovia
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | palanga
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | papara
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | aykhal
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | pedro ii
# Processing Record 21 of Set 2 | lac du bonnet
# Processing Record 22 of Set 2 | magapit
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | hami
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | hualmay
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | suntar
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | barra
# Processing Record 34 of Set 2 | malibu
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | arlit
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | dusti
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | durban
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | keffi
# Processing Record 45 of Set 2 | vao
# Processing Record 46 of Set 2 | victoria
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | balkanabat
# Processing Record 50 of Set 2 | lahij
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | fortuna
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | karpogory
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | andenes
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | sao miguel
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | lulea
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | mayumba
# Processing Record 14 of Set 3 | odienne
# Processing Record 15 of Set 3 | kavieng
# Processing Record 16 of Set 3 | shimoda
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | abu samrah
# Processing Record 19 of Set 3 | tshikapa
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | kambove
# Processing Record 22 of Set 3 | luwuk
# Processing Record 23 of Set 3 | rorvik
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | puerto carreno
# Processing Record 26 of Set 3 | topi
# Processing Record 27 of Set 3 | caravelas
# Processing Record 28 of Set 3 | yenagoa
# Processing Record 29 of Set 3 | lagos de moreno
# Processing Record 30 of Set 3 | kidal
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | san jose
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | srivardhan
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | chalchihuites
# Processing Record 41 of Set 3 | emerald
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | pimenta bueno
# Processing Record 46 of Set 3 | vila franca do campo
# Processing Record 47 of Set 3 | bintulu
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | la asuncion
# Processing Record 50 of Set 3 | castro
# Processing Record 1 of Set 4 | quatre cocos
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | itarema
# Processing Record 4 of Set 4 | ullapool
# Processing Record 5 of Set 4 | penzance
# Processing Record 6 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | bonavista
# Processing Record 12 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 4 | kolpashevo
# Processing Record 14 of Set 4 | lashio
# Processing Record 15 of Set 4 | esmeraldas
# Processing Record 16 of Set 4 | anadyr
# Processing Record 17 of Set 4 | ambulu
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | kem
# Processing Record 20 of Set 4 | sicamous
# Processing Record 21 of Set 4 | kangaba
# Processing Record 22 of Set 4 | baykit
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | cam ranh
# Processing Record 25 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | hirado
# Processing Record 28 of Set 4 | murindo
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | lorengau
# Processing Record 31 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 4 | richards bay
# Processing Record 33 of Set 4 | the pas
# Processing Record 34 of Set 4 | ishigaki
# Processing Record 35 of Set 4 | ponta delgada
# Processing Record 36 of Set 4 | kutum
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | yokadouma
# Processing Record 39 of Set 4 | jibuti
# Processing Record 40 of Set 4 | port hedland
# Processing Record 41 of Set 4 | jiblah
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | port lincoln
# Processing Record 44 of Set 4 | zheleznodorozhnyy
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | puerto leguizamo
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | betare oya
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | flinders
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | atar
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | cervo
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | payakumbuh
# Processing Record 8 of Set 5 | kuloy
# Processing Record 9 of Set 5 | aripuana
# Processing Record 10 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 11 of Set 5 | tuatapere
# Processing Record 12 of Set 5 | margate
# Processing Record 13 of Set 5 | the valley
# Processing Record 14 of Set 5 | cascais
# Processing Record 15 of Set 5 | muroto
# Processing Record 16 of Set 5 | marrakesh
# Processing Record 17 of Set 5 | caborca
# Processing Record 18 of Set 5 | khelyulya
# Processing Record 19 of Set 5 | toora-khem
# Processing Record 20 of Set 5 | makakilo city
# Processing Record 21 of Set 5 | gali
# Processing Record 22 of Set 5 | ulaangom
# Processing Record 23 of Set 5 | netivot
# Processing Record 24 of Set 5 | de-kastri
# Processing Record 25 of Set 5 | cape town
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | luderitz
# Processing Record 28 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 5 | beamsville
# Processing Record 30 of Set 5 | alpena
# Processing Record 31 of Set 5 | sur
# Processing Record 32 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 5 | srednekolymsk
# Processing Record 34 of Set 5 | tari
# Processing Record 35 of Set 5 | numan
# Processing Record 36 of Set 5 | alta floresta
# Processing Record 37 of Set 5 | morondava
# Processing Record 38 of Set 5 | zlobin
# Processing Record 39 of Set 5 | borogontsy
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | khonsa
# Processing Record 42 of Set 5 | buin
# Processing Record 43 of Set 5 | killybegs
# Processing Record 44 of Set 5 | kharp
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 5 | bandar penggaram
# City not found. Skipping...
# Processing Record 48 of Set 5 | kuala terengganu
# Processing Record 49 of Set 5 | port hardy
# Processing Record 50 of Set 5 | burica
# City not found. Skipping...
# Processing Record 1 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 6 | huilong
# Processing Record 3 of Set 6 | tuyen quang
# Processing Record 4 of Set 6 | malanje
# Processing Record 5 of Set 6 | hayden
# Processing Record 6 of Set 6 | ust-nera
# Processing Record 7 of Set 6 | manokwari
# Processing Record 8 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | manzil salim
# Processing Record 11 of Set 6 | port-gentil
# Processing Record 12 of Set 6 | maieru
# Processing Record 13 of Set 6 | vikindu
# Processing Record 14 of Set 6 | ankpa
# Processing Record 15 of Set 6 | belaya gora
# Processing Record 16 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | agadir
# Processing Record 22 of Set 6 | marawi
# Processing Record 23 of Set 6 | matagami
# Processing Record 24 of Set 6 | mehamn
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | brae
# Processing Record 27 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | manadhoo
# Processing Record 29 of Set 6 | erzin
# Processing Record 30 of Set 6 | bud
# Processing Record 31 of Set 6 | opuwo
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | canete
# Processing Record 34 of Set 6 | dalvik
# Processing Record 35 of Set 6 | aginskoye
# Processing Record 36 of Set 6 | cayenne
# Processing Record 37 of Set 6 | hailar
# Processing Record 38 of Set 6 | chantada
# Processing Record 39 of Set 6 | buchanan
# Processing Record 40 of Set 6 | lavrentiya
# Processing Record 41 of Set 6 | vodnyy
# Processing Record 42 of Set 6 | alghero
# Processing Record 43 of Set 6 | ixtapa
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | inta
# Processing Record 46 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 6 | hornepayne
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | trairi
# Processing Record 50 of Set 6 | jiaojiang
# Processing Record 1 of Set 7 | esterhazy
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 7 | mount pleasant
# Processing Record 5 of Set 7 | labuhan
# Processing Record 6 of Set 7 | wangou
# Processing Record 7 of Set 7 | binzhou
# Processing Record 8 of Set 7 | changji
# Processing Record 9 of Set 7 | poum
# Processing Record 10 of Set 7 | etampes
# Processing Record 11 of Set 7 | nadym
# Processing Record 12 of Set 7 | kruisfontein
# Processing Record 13 of Set 7 | yagodnoye
# Processing Record 14 of Set 7 | yeltsovka
# City not found. Skipping...
# Processing Record 15 of Set 7 | empangeni
# Processing Record 16 of Set 7 | polican
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | burnie
# Processing Record 19 of Set 7 | pacific grove
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | biloela
# Processing Record 22 of Set 7 | cruzeiro do sul
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | provideniya
# Processing Record 25 of Set 7 | zaragoza
# Processing Record 26 of Set 7 | vilyuysk
# Processing Record 27 of Set 7 | bulgan
# Processing Record 28 of Set 7 | koratla
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 7 | turukhansk
# Processing Record 32 of Set 7 | kabwe
# Processing Record 33 of Set 7 | palamos
# Processing Record 34 of Set 7 | banda aceh
# Processing Record 35 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | tadine
# Processing Record 37 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 7 | zeya
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | vila
# Processing Record 41 of Set 7 | panzhihua
# Processing Record 42 of Set 7 | ruidoso
# Processing Record 43 of Set 7 | saint-georges
# Processing Record 44 of Set 7 | viytivka
# Processing Record 45 of Set 7 | vyartsilya
# Processing Record 46 of Set 7 | daru
# Processing Record 47 of Set 7 | deer lake
# Processing Record 48 of Set 7 | polunochnoye
# Processing Record 49 of Set 7 | mount gambier
# Processing Record 50 of Set 7 | jieshi
# Processing Record 1 of Set 8 | imeni poliny osipenko
# Processing Record 2 of Set 8 | plettenberg bay
# Processing Record 3 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 8 | kiama
# Processing Record 5 of Set 8 | goshen
# Processing Record 6 of Set 8 | marystown
# Processing Record 7 of Set 8 | churapcha
# Processing Record 8 of Set 8 | tilichiki
# Processing Record 9 of Set 8 | tautira
# Processing Record 10 of Set 8 | hachinohe
# Processing Record 11 of Set 8 | mpika
# Processing Record 12 of Set 8 | ibra
# Processing Record 13 of Set 8 | vuktyl
# Processing Record 14 of Set 8 | pokaran
# Processing Record 15 of Set 8 | katobu
# Processing Record 16 of Set 8 | severo-yeniseyskiy
# Processing Record 17 of Set 8 | dalby
# Processing Record 18 of Set 8 | kasamwa
# Processing Record 19 of Set 8 | jiexiu
# Processing Record 20 of Set 8 | zyryanskoye
# Processing Record 21 of Set 8 | gat
# Processing Record 22 of Set 8 | cairns
# Processing Record 23 of Set 8 | koumac
# Processing Record 24 of Set 8 | harrismith
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | calolziocorte
# Processing Record 27 of Set 8 | malkangiri
# Processing Record 28 of Set 8 | malpe
# Processing Record 29 of Set 8 | markapur
# Processing Record 30 of Set 8 | vostochnyy
# Processing Record 31 of Set 8 | jeremie
# Processing Record 32 of Set 8 | vestmannaeyjar
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | pribelskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | haines junction
# Processing Record 36 of Set 8 | ingham
# Processing Record 37 of Set 8 | dauphin
# Processing Record 38 of Set 8 | chuy
# Processing Record 39 of Set 8 | lata
# Processing Record 40 of Set 8 | sohag
# Processing Record 41 of Set 8 | saldanha
# Processing Record 42 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 43 of Set 8 | leicester
# Processing Record 44 of Set 8 | flin flon
# Processing Record 45 of Set 8 | ancud
# Processing Record 46 of Set 8 | shache
# Processing Record 47 of Set 8 | tianpeng
# Processing Record 48 of Set 8 | loandjili
# Processing Record 49 of Set 8 | diamantino
# Processing Record 50 of Set 8 | roald
# Processing Record 1 of Set 9 | thabazimbi
# Processing Record 2 of Set 9 | dharchula
# Processing Record 3 of Set 9 | yangambi
# Processing Record 4 of Set 9 | berestechko
# Processing Record 5 of Set 9 | aklavik
# Processing Record 6 of Set 9 | kusti
# Processing Record 7 of Set 9 | khandbari
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | castanos
# Processing Record 10 of Set 9 | nome
# Processing Record 11 of Set 9 | nikolskoye
# Processing Record 12 of Set 9 | muskegon
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | deshnok
# Processing Record 15 of Set 9 | selenginsk
# Processing Record 16 of Set 9 | akureyri
# Processing Record 17 of Set 9 | ullerslev
# Processing Record 18 of Set 9 | cabedelo
# Processing Record 19 of Set 9 | merced
# Processing Record 20 of Set 9 | rio gallegos
# Processing Record 21 of Set 9 | terra santa
# Processing Record 22 of Set 9 | kembe
# Processing Record 23 of Set 9 | tygda
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | eshowe
# Processing Record 26 of Set 9 | zalantun
# Processing Record 27 of Set 9 | faanui
# Processing Record 28 of Set 9 | tumaco
# Processing Record 29 of Set 9 | west bay
# Processing Record 30 of Set 9 | garwolin
# Processing Record 31 of Set 9 | varazdin
# Processing Record 32 of Set 9 | port-cartier
# Processing Record 33 of Set 9 | manoel urbano
# Processing Record 34 of Set 9 | mandera
# Processing Record 35 of Set 9 | berlevag
# Processing Record 36 of Set 9 | roma
# Processing Record 37 of Set 9 | kitovo
# Processing Record 38 of Set 9 | ataco
# Processing Record 39 of Set 9 | isla vista
# Processing Record 40 of Set 9 | omagh
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | antropovo
# Processing Record 43 of Set 9 | saint-joseph
# Processing Record 44 of Set 9 | prince rupert
# Processing Record 45 of Set 9 | guamuchil
# Processing Record 46 of Set 9 | saint-francois
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | batagay-alyta
# Processing Record 49 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 9 | sawang daen din
# Processing Record 1 of Set 10 | khasan
# Processing Record 2 of Set 10 | agaro
# Processing Record 3 of Set 10 | blyth
# Processing Record 4 of Set 10 | bahua
# Processing Record 5 of Set 10 | ustka
# Processing Record 6 of Set 10 | puerto colombia
# Processing Record 7 of Set 10 | hilliard
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | richfield
# Processing Record 10 of Set 10 | turka
# Processing Record 11 of Set 10 | leona vicario
# Processing Record 12 of Set 10 | kondol
# Processing Record 13 of Set 10 | teguldet
# Processing Record 14 of Set 10 | ginda
# Processing Record 15 of Set 10 | pontes e lacerda
# Processing Record 16 of Set 10 | namibe
# Processing Record 17 of Set 10 | laem sing
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | saint anthony
# Processing Record 20 of Set 10 | den helder
# Processing Record 21 of Set 10 | bure
# Processing Record 22 of Set 10 | shenjiamen
# Processing Record 23 of Set 10 | bassila
# Processing Record 24 of Set 10 | belmonte
# Processing Record 25 of Set 10 | esperance
# Processing Record 26 of Set 10 | severnoye
# Processing Record 27 of Set 10 | casper
# Processing Record 28 of Set 10 | dolores
# Processing Record 29 of Set 10 | los llanos de aridane
# Processing Record 30 of Set 10 | colares
# Processing Record 31 of Set 10 | ust-maya
# Processing Record 32 of Set 10 | chifeng
# Processing Record 33 of Set 10 | cap malheureux
# Processing Record 34 of Set 10 | acapulco
# Processing Record 35 of Set 10 | liapades
# City not found. Skipping...
# Processing Record 36 of Set 10 | nyagan
# Processing Record 37 of Set 10 | portland
# Processing Record 38 of Set 10 | ikere
# Processing Record 39 of Set 10 | tupancireta
# Processing Record 40 of Set 10 | bima
# Processing Record 41 of Set 10 | nehe
# Processing Record 42 of Set 10 | kilindoni
# Processing Record 43 of Set 10 | poronaysk
# Processing Record 44 of Set 10 | beloha
# Processing Record 45 of Set 10 | zambezi
# Processing Record 46 of Set 10 | lively
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | corinto
# Processing Record 49 of Set 10 | parabel
# Processing Record 50 of Set 10 | alakurtti
# Processing Record 1 of Set 11 | ursulo galvan
# Processing Record 2 of Set 11 | jalu
# Processing Record 3 of Set 11 | trelew
# Processing Record 4 of Set 11 | santo tomas
# Processing Record 5 of Set 11 | kautokeino
# Processing Record 6 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 11 | broome
# Processing Record 8 of Set 11 | asau
# Processing Record 9 of Set 11 | bairiki
# Processing Record 10 of Set 11 | pevek
# Processing Record 11 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 11 | sola
# Processing Record 13 of Set 11 | mogadishu
# Processing Record 14 of Set 11 | celestun
# Processing Record 15 of Set 11 | soe
# Processing Record 16 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 11 | lagos
# Processing Record 18 of Set 11 | huarmey
# Processing Record 19 of Set 11 | wawa
# Processing Record 20 of Set 11 | sakakah
# Processing Record 21 of Set 11 | belene
# Processing Record 22 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 23 of Set 11 | tarko-sale
# Processing Record 24 of Set 11 | swidwin
# Processing Record 25 of Set 11 | tuy hoa
# Processing Record 26 of Set 11 | miri
# Processing Record 27 of Set 11 | ventspils
# Processing Record 28 of Set 11 | buraydah
# Processing Record 29 of Set 11 | antofagasta
# Processing Record 30 of Set 11 | port macquarie
# Processing Record 31 of Set 11 | sovetskiy
# Processing Record 32 of Set 11 | nouakchott
# Processing Record 33 of Set 11 | vysokaya gora
# Processing Record 34 of Set 11 | candido de abreu
# Processing Record 35 of Set 11 | mandalgovi
# Processing Record 36 of Set 11 | kayerkan
# Processing Record 37 of Set 11 | smidovich
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | muscat
# Processing Record 40 of Set 11 | baturaja
# Processing Record 41 of Set 11 | labuan
# Processing Record 42 of Set 11 | aldan
# Processing Record 43 of Set 11 | osorno
# Processing Record 44 of Set 11 | mariel
# Processing Record 45 of Set 11 | praya
# Processing Record 46 of Set 11 | sibu
# Processing Record 47 of Set 11 | tuktoyaktuk
# Processing Record 48 of Set 11 | vanavara
# Processing Record 49 of Set 11 | yarim
# Processing Record 50 of Set 11 | grand gaube
# Processing Record 1 of Set 12 | kulhudhuffushi
# Processing Record 2 of Set 12 | jamame
# Processing Record 3 of Set 12 | letpadan
# Processing Record 4 of Set 12 | cururupu
# Processing Record 5 of Set 12 | umea
# Processing Record 6 of Set 12 | gustavo diaz ordaz
# Processing Record 7 of Set 12 | fredericksburg
# Processing Record 8 of Set 12 | kall
# Processing Record 9 of Set 12 | viedma
# Processing Record 10 of Set 12 | mayya
# Processing Record 11 of Set 12 | keflavik
# Processing Record 12 of Set 12 | ta khmau
# Processing Record 13 of Set 12 | hare bay
# Processing Record 14 of Set 12 | deputatskiy
# Processing Record 15 of Set 12 | hambantota
# Processing Record 16 of Set 12 | tacuati
# Processing Record 17 of Set 12 | zhuhai
# Processing Record 18 of Set 12 | hirara
# Processing Record 19 of Set 12 | beringovskiy
# Processing Record 20 of Set 12 | riyadh
# Processing Record 21 of Set 12 | maridi
# Processing Record 22 of Set 12 | kharan
# Processing Record 23 of Set 12 | ulagan
# Processing Record 24 of Set 12 | nha trang
# Processing Record 25 of Set 12 | gurupa
# Processing Record 26 of Set 12 | north bend
# Processing Record 27 of Set 12 | alexandria
# Processing Record 28 of Set 12 | kapuskasing
# Processing Record 29 of Set 12 | capitao poco
# Processing Record 30 of Set 12 | lovozero
# Processing Record 31 of Set 12 | zhezkazgan
# Processing Record 32 of Set 12 | dali
# Processing Record 33 of Set 12 | saint-pierre
# Processing Record 34 of Set 12 | chumikan
# Processing Record 35 of Set 12 | creston
# Processing Record 36 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 12 | chunhuhub
# Processing Record 38 of Set 12 | ahipara
# Processing Record 39 of Set 12 | tamandare
# Processing Record 40 of Set 12 | manado
# Processing Record 41 of Set 12 | marzuq
# Processing Record 42 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 12 | amantea
# Processing Record 44 of Set 12 | dunedin
# Processing Record 45 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 12 | ossora
# Processing Record 47 of Set 12 | glubokiy
# Processing Record 48 of Set 12 | itoman
# Processing Record 49 of Set 12 | sosnogorsk
# Processing Record 50 of Set 12 | san cristobal
# Processing Record 1 of Set 13 | mooi river
# City not found. Skipping...
# Processing Record 2 of Set 13 | linhares
# Processing Record 3 of Set 13 | pyay
# Processing Record 4 of Set 13 | qaqortoq
# Processing Record 5 of Set 13 | pingliang
# Processing Record 6 of Set 13 | lang son
# Processing Record 7 of Set 13 | airai
# Processing Record 8 of Set 13 | heihe
# Processing Record 9 of Set 13 | baghdad
# Processing Record 10 of Set 13 | lagoa
# Processing Record 11 of Set 13 | teacapan
# Processing Record 12 of Set 13 | camana
# Processing Record 13 of Set 13 | zaozhuang
# Processing Record 14 of Set 13 | madison
# Processing Record 15 of Set 13 | guane
# Processing Record 16 of Set 13 | conde
# Processing Record 17 of Set 13 | filingue
# Processing Record 18 of Set 13 | bereda
# Processing Record 19 of Set 13 | okha
# Processing Record 20 of Set 13 | soma
# Processing Record 21 of Set 13 | talcahuano
# Processing Record 22 of Set 13 | egvekinot
# Processing Record 23 of Set 13 | broken hill
# Processing Record 24 of Set 13 | semme
# Processing Record 25 of Set 13 | teknaf
# Processing Record 26 of Set 13 | ferkessedougou
# Processing Record 27 of Set 13 | ada
# Processing Record 28 of Set 13 | comodoro rivadavia
# Processing Record 29 of Set 13 | fort nelson
# Processing Record 30 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 13 | gubbi
# Processing Record 32 of Set 13 | sabang
# Processing Record 33 of Set 13 | fare
# Processing Record 34 of Set 13 | necochea
# Processing Record 35 of Set 13 | phuket
# Processing Record 36 of Set 13 | bilibino
# Processing Record 37 of Set 13 | bloemfontein
# Processing Record 38 of Set 13 | susanville
# Processing Record 39 of Set 13 | loikaw
# Processing Record 40 of Set 13 | ukiah
# Processing Record 41 of Set 13 | serebryansk
# Processing Record 42 of Set 13 | nouadhibou
# Processing Record 43 of Set 13 | doka
# Processing Record 44 of Set 13 | klaksvik
# Processing Record 45 of Set 13 | penapolis
# Processing Record 46 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 13 | russell
# Processing Record 48 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 49 of Set 13 | bonthe
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | halifax
# Processing Record 2 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 14 | santa lucia
# Processing Record 5 of Set 14 | santa leopoldina
# Processing Record 6 of Set 14 | eureka
# Processing Record 7 of Set 14 | matara
# Processing Record 8 of Set 14 | telafas
# Processing Record 9 of Set 14 | susangerd
# Processing Record 10 of Set 14 | mirnyy
# Processing Record 11 of Set 14 | ust-koksa
# Processing Record 12 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 14 | changde
# Processing Record 14 of Set 14 | praia
# Processing Record 15 of Set 14 | amazar
# Processing Record 16 of Set 14 | marienburg
# Processing Record 17 of Set 14 | kiunga
# Processing Record 18 of Set 14 | boa vista
# Processing Record 19 of Set 14 | bridgetown
# Processing Record 20 of Set 14 | launceston
# Processing Record 21 of Set 14 | boralday
# Processing Record 22 of Set 14 | kalga
# Processing Record 23 of Set 14 | cantaura
# Processing Record 24 of Set 14 | muravlenko
# Processing Record 25 of Set 14 | san carlos
# Processing Record 26 of Set 14 | codajas
# Processing Record 27 of Set 14 | darhan
# Processing Record 28 of Set 14 | biak
# Processing Record 29 of Set 14 | ouesso
# Processing Record 30 of Set 14 | talaya
# Processing Record 31 of Set 14 | tweed
# Processing Record 32 of Set 14 | terrace
# Processing Record 33 of Set 14 | mgachi
# Processing Record 34 of Set 14 | sistranda
# Processing Record 35 of Set 14 | cockburn town
# Processing Record 36 of Set 14 | ahuimanu
# Processing Record 37 of Set 14 | behshahr
# Processing Record 38 of Set 14 | el alto
# Processing Record 39 of Set 14 | salalah
# Processing Record 40 of Set 14 | sayyan
# Processing Record 41 of Set 14 | matay
# Processing Record 42 of Set 14 | oussouye
# Processing Record 43 of Set 14 | kununurra
# Processing Record 44 of Set 14 | vega de alatorre
# Processing Record 45 of Set 14 | porto velho
# Processing Record 46 of Set 14 | guirim
# Processing Record 47 of Set 14 | maragogi
# Processing Record 48 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 14 | adrar
# Processing Record 50 of Set 14 | blagoyevo
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | dickinson
# Processing Record 3 of Set 15 | port-de-bouc
# Processing Record 4 of Set 15 | davidson
# Processing Record 5 of Set 15 | neryungri
# Processing Record 6 of Set 15 | linguere
# Processing Record 7 of Set 15 | ondangwa
# Processing Record 8 of Set 15 | khandyga
# Processing Record 9 of Set 15 | kaoma
# Processing Record 10 of Set 15 | sao felix do xingu
# Processing Record 11 of Set 15 | port moresby
# Processing Record 12 of Set 15 | puerto penasco
# Processing Record 13 of Set 15 | tanout
# Processing Record 14 of Set 15 | koyilandi
# City not found. Skipping...
# Processing Record 15 of Set 15 | hamilton
# Processing Record 16 of Set 15 | yar-sale
# Processing Record 17 of Set 15 | kendal
# Processing Record 18 of Set 15 | gerash
# Processing Record 19 of Set 15 | gueugnon
# Processing Record 20 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 15 | tazovskiy
# Processing Record 22 of Set 15 | brownsville
# Processing Record 23 of Set 15 | watsa
# Processing Record 24 of Set 15 | madera
# Processing Record 25 of Set 15 | urumqi
# Processing Record 26 of Set 15 | swellendam
# Processing Record 27 of Set 15 | mahon
# Processing Record 28 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 29 of Set 15 | taltal
# Processing Record 30 of Set 15 | bandarbeyla
# Processing Record 31 of Set 15 | kamenka
# Processing Record 32 of Set 15 | mitsamiouli
# Processing Record 33 of Set 15 | ailigandi
# Processing Record 34 of Set 15 | coahuayana
# Processing Record 35 of Set 15 | ginir
# Processing Record 36 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 15 | kungurtug
# Processing Record 38 of Set 15 | birjand
# Processing Record 39 of Set 15 | montepuez
# Processing Record 40 of Set 15 | balabac
# Processing Record 41 of Set 15 | puerto maldonado
# Processing Record 42 of Set 15 | manggar
# Processing Record 43 of Set 15 | hulan
# Processing Record 44 of Set 15 | forest park
# Processing Record 45 of Set 15 | kedrovyy
# Processing Record 46 of Set 15 | letka
# Processing Record 47 of Set 15 | marfino
# Processing Record 48 of Set 15 | nabire
# Processing Record 49 of Set 15 | vilhena
# Processing Record 50 of Set 15 | ayan
# Processing Record 1 of Set 16 | sarkand
# Processing Record 2 of Set 16 | bayangol
# Processing Record 3 of Set 16 | obera
# Processing Record 4 of Set 16 | tynda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Narino  -3.7703  -70.3831     75.04        95          80
# 1        Inhambane -23.8650   35.3833     80.71        78          98
# 2             Tura  25.5198   90.2201     56.62        52           5
# 3            Kapaa  22.0752 -159.3190     81.48        70          40
# 4          Rikitea -23.1203 -134.9692     79.70        76           3
# 5          Mataura -46.1927  168.8643     60.30        41          57
# 6         Menongue -14.6585   17.6910     62.80        96         100
# 7  Arraial Do Cabo -22.9661  -42.0278     75.74        83          66
# 8      Pangnirtung  66.1451  -65.7125     -1.80       100         100
# 9           Dikson  73.5069   80.5464     -8.95        92         100
#
#    Wind Speed Current Description
# 0        1.74       moderate rain
# 1       14.45     overcast clouds
# 2        3.38           clear sky
# 3        4.61    scattered clouds
# 4       16.17           clear sky
# 5        5.64       broken clouds
# 6        5.39          light rain
# 7       10.42       broken clouds
# 8        4.38     overcast clouds
# 9       25.84     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = city_data_df[["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = new_column_order
# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Narino  -3.7703  -70.3831     75.04        95          80
# 1      Inhambane -23.8650   35.3833     80.71        78          98
# 2           Tura  25.5198   90.2201     56.62        52           5
# 3          Kapaa  22.0752 -159.3190     81.48        70          40
# 4        Rikitea -23.1203 -134.9692     79.70        76           3
#
#    Wind Speed Current Description
# 0        1.74       moderate rain
# 1       14.45     overcast clouds
# 2        3.38           clear sky
# 3        4.61    scattered clouds
# 4       16.17           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
